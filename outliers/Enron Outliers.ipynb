# %%
import pickle
import sys
import matplotlib.pyplot
sys.path.append("../tools/")
from feature_format import featureFormat, targetFeatureSplit

from operator import itemgetter

# %%
### read in data dictionary, convert to numpy array
data_dict = pickle.load( open("../final_project/final_project_dataset.pkl", "r") )
features = ["salary", "bonus"]

data_dict.pop( 'TOTAL', 0 ) 

data = featureFormat(data_dict, features)

# %%
### your code below
for point in data:
    salary = point[0]
    bonus = point[1]
    matplotlib.pyplot.scatter( salary, bonus )

matplotlib.pyplot.xlabel("salary")
matplotlib.pyplot.ylabel("bonus")
matplotlib.pyplot.show()

# %%
sorted([(p, data_dict[p]['salary'], data_dict[p]['bonus']) for p in data_dict], key=itemgetter(1))
# Out:
# [('BANNANTINE JAMES M', 477, 'NaN'),
#  ('GRAY RODNEY', 6615, 'NaN'),
#  ('WESTFAHL RICHARD K', 63744, 'NaN'),
#  ('REYNOLDS LAWRENCE', 76399, 100000),
#  ('BAZELIDES PHILIP J', 80818, 'NaN'),
#  ('IZZO LAWRENCE L', 85274, 'NaN'),
#  ('OVERDYKE JR JERE C', 94941, 'NaN'),
#  ('REDMOND BRIAN L', 96840, 'NaN'),
#  ('HUMPHREY GENE E', 130724, 'NaN'),
#  ('YEAGER F SCOTT', 158403, 'NaN'),
#  ('SULLIVAN-SHAKLOVITZ COLLEEN', 162779, 100000),
#  ('ELLIOTT STEVEN', 170941, 350000),
#  ('KISHKILL JOSEPH G', 174246, 'NaN'),
#  ('ECHOLS JOHN B', 182245, 200000),
#  ('CUMBERLAND MICHAEL S', 184899, 325000),
#  ('BERGSIEKER RICHARD P', 187922, 250000),
#  ('GAHN ROBERT S', 192008, 509870),
#  ('PIPER GREGORY F', 197091, 400000),
#  ('FITZGERALD JAY L', 199157, 350000),
#  ('ALLEN PHILLIP K', 201955, 4175000),
#  ('DEFFNER JOSEPH M', 206121, 600000),
#  ('DETMERING TIMOTHY J', 210500, 425000),
#  ('DURAN WILLIAM D', 210692, 750000),
#  ('HICKERSON GARY J', 211788, 1700000),
#  ('SHELBY REX', 211844, 200000),
#  ('BIBI PHILIPPE A', 213625, 1000000),
#  ('BELDEN TIMOTHY N', 213999, 5249999),
#  ('BERBERIAN DAVID', 216582, 'NaN'),
#  ('DODSON KEITH', 221003, 70000),
#  ('THORN TERENCE H', 222093, 'NaN'),
#  ('KOPPER MICHAEL J', 224305, 800000),
#  ('MURRAY JULIA H', 229284, 400000),
#  ('BECK SALLY W', 231330, 700000),
#  ('GARLAND C KEVIN', 231946, 850000),
#  ('LINDHOLM TOD A', 236457, 200000),
#  ('STABLER FRANK', 239502, 500000),
#  ('BAY FRANKLIN R', 239671, 400000),
#  ('CALGER CHRISTOPHER F', 240189, 1250000),
#  ('HANNON KEVIN P', 243293, 1500000),
#  ('TILNEY ELIZABETH A', 247338, 300000),
#  ('BUCHANAN HAROLD G', 248017, 500000),
#  ('SHARP VICTORIA T', 248146, 600000),
#  ('BLACHMAN JEREMY M', 248546, 850000),
#  ('RIEKER PAULA H', 249201, 700000),
#  ('DIETRICH JANET R', 250100, 600000),
#  ('MULLER MARK S', 251654, 1100000),
#  ('SUNDE MARTIN', 257486, 700000),
#  ('WASAFF GEORGE', 259996, 325000),
#  ('BUTTS ROBERT H', 261516, 750000),
#  ('CARTER REBECCA C', 261809, 300000),
#  ('PAI LOU L', 261879, 1000000),
#  ('HERMANN ROBERT J', 262663, 700000),
#  ('DIMICHELE RICHARD G', 262788, 1000000),
#  ('MCCLELLAN GEORGE', 263413, 900000),
#  ('TAYLOR MITCHELL S', 265214, 600000),
#  ('MORDAUNT KRISTINA M', 267093, 325000),
#  ('BAXTER JOHN C', 267102, 1200000),
#  ('SHAPIRO RICHARD S', 269076, 650000),
#  ('KITCHEN LOUISE', 271442, 3100000),
#  ('GOLD JOSEPH', 272880, 750000),
#  ('LEFF DANIEL P', 273746, 1000000),
#  ('GLISAN JR BEN F', 274975, 600000),
#  ('KAMINSKI WINCENTY J', 275101, 400000),
#  ('BOWEN JR RAYMOND M', 278601, 1350000),
#  ('DONAHUE JR JEFFREY M', 278601, 800000),
#  ('COLWELL WESLEY', 288542, 1200000),
#  ('JACKSON CHARLENE R', 288558, 250000),
#  ('UMANOFF ADAM S', 288589, 788750),
#  ('SHANKMAN JEFFREY A', 304110, 2000000),
#  ('FALLON JAMES B', 304588, 2500000),
#  ('KOENIG MARK E', 309946, 700000),
#  ('COX DAVID', 314288, 800000),
#  ('WHITE JR THOMAS E', 317543, 450000),
#  ('OLSON CINDY K', 329078, 750000),
#  ('BUY RICHARD B', 330546, 900000),
#  ('LAVORATO JOHN J', 339288, 8000000),
#  ('MARTIN AMANDA K', 349487, 'NaN'),
#  ('WALLS JR ROBERT H', 357091, 850000),
#  ('MCCONNELL MICHAEL S', 365038, 1100000),
#  ('DELAINEY DAVID W', 365163, 3000000),
#  ('METTS MARK', 365788, 600000),
#  ('MCMAHON JEFFREY', 370448, 2600000),
#  ('HAEDICKE MARK E', 374125, 1150000),
#  ('KEAN STEVEN J', 404338, 1000000),
#  ('CAUSEY RICHARD A', 415189, 1000000),
#  ('RICE KENNETH D', 420636, 1750000),
#  ('SHERRIFF JOHN R', 428780, 1500000),
#  ('FASTOW ANDREW S', 440698, 1300000),
#  ('DERRICK JR. JAMES V', 492375, 800000),
#  ('WHALLEY LAWRENCE G', 510364, 3000000),
#  ('PICKERING MARK R', 655037, 300000),
#  ('FREVERT MARK A', 1060932, 2000000),
#  ('LAY KENNETH L', 1072321, 7000000),
#  ('SKILLING JEFFREY K', 1111258, 5600000),
#  ('CORDES WILLIAM R', 'NaN', 'NaN'),
#  ('MEYER ROCKFORD G', 'NaN', 'NaN'),
#  ('HORTON STANLEY C', 'NaN', 'NaN'),
#  ('GIBBS DANA R', 'NaN', 'NaN'),
#  ('LOWRY CHARLES P', 'NaN', 'NaN'),
#  ('WALTERS GARETH W', 'NaN', 'NaN'),
#  ('CHAN RONNIE', 'NaN', 'NaN'),
#  ('BELFER ROBERT', 'NaN', 'NaN'),
#  ('WODRASKA JOHN', 'NaN', 'NaN'),
#  ('URQUHART JOHN A', 'NaN', 'NaN'),
#  ('WHALEY DAVID A', 'NaN', 'NaN'),
#  ('HAUG DAVID L', 'NaN', 'NaN'),
#  ('MENDELSOHN JOHN', 'NaN', 'NaN'),
#  ('CLINE KENNETH W', 'NaN', 'NaN'),
#  ('LEWIS RICHARD', 'NaN', 'NaN'),
#  ('HAYES ROBERT E', 'NaN', 'NaN'),
#  ('MCCARTY DANNY J', 'NaN', 'NaN'),
#  ('WAKEHAM JOHN', 'NaN', 'NaN'),
#  ('POWERS WILLIAM', 'NaN', 'NaN'),
#  ('DUNCAN JOHN H', 'NaN', 'NaN'),
#  ('LEMAISTRE CHARLES', 'NaN', 'NaN'),
#  ('PIRO JIM', 'NaN', 'NaN'),
#  ('WROBEL BRUCE', 'NaN', 'NaN'),
#  ('MEYER JEROME J', 'NaN', 'NaN'),
#  ('MCDONALD REBECCA', 'NaN', 'NaN'),
#  ('SCRIMSHAW MATTHEW', 'NaN', 'NaN'),
#  ('GATHMANN WILLIAM D', 'NaN', 'NaN'),
#  ('GILLIS JOHN', 'NaN', 'NaN'),
#  ('MORAN MICHAEL P', 'NaN', 'NaN'),
#  ('FOY JOE', 'NaN', 'NaN'),
#  ('LOCKHART EUGENE E', 'NaN', 'NaN'),
#  ('PEREIRA PAULO V. FERRAZ', 'NaN', 'NaN'),
#  ('BLAKE JR. NORMAN P', 'NaN', 'NaN'),
#  ('SHERRICK JEFFREY B', 'NaN', 'NaN'),
#  ('PRENTICE JAMES', 'NaN', 'NaN'),
#  ('THE TRAVEL AGENCY IN THE PARK', 'NaN', 'NaN'),
#  ('NOLES JAMES L', 'NaN', 'NaN'),
#  ('FOWLER PEGGY', 'NaN', 'NaN'),
#  ('CHRISTODOULOU DIOMEDES', 'NaN', 'NaN'),
#  ('JAEDICKE ROBERT', 'NaN', 'NaN'),
#  ('WINOKUR JR. HERBERT S', 'NaN', 'NaN'),
#  ('BROWN MICHAEL', 'NaN', 'NaN'),
#  ('BADUM JAMES P', 'NaN', 'NaN'),
#  ('HUGHES JAMES A', 'NaN', 'NaN'),
#  ('BHATNAGAR SANJAY', 'NaN', 'NaN'),
#  ('YEAP SOON', 'NaN', 'NaN'),
#  ('HIRKO JOSEPH', 'NaN', 'NaN'),
#  ('HAYSLETT RODERICK J', 'NaN', 'NaN'),
#  ('FUGH JOHN L', 'NaN', 'NaN'),
#  ('SAVAGE FRANK', 'NaN', 'NaN'),
#  ('GRAMM WENDY L', 'NaN', 'NaN')]
